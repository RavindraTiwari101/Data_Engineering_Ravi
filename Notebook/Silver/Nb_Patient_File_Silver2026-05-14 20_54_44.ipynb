# %%
# %sql

select * from learning_catalog.learning_Bronze.dfpatients

# %%
# %sql

CREATE TABLE learning_catalog.learning_gold.dfpatient
AS
SELECT * FROM learning_catalog.learning_silver.dfpatient where 1=2

# %%
# %sql
insert into learning_catalog.learning_silver.dfpatient
from learning_catalog.learning_Bronze.dfpatients
