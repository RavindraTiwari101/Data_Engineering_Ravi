-- %%
-- Create table in silver layer with correct data type :-
CREATE OR REPLACE TABLE learning_catalog.learning_silver.CleanedMonthlySales
(
    sale_id INTEGER, 
    product string,
    category string,
    quantity INTEGER,
    price DOUBLE,
    sale_date DATE,
    region string,
    ingest_ts timestamp
);

select * from learning_catalog.learning_silver.CleanedMonthlySales
describe learning_catalog.learning_silver.CleanedMonthlySales
describe history learning_catalog.learning_silver.CleanedMonthlySales
TRUNCATE TABLE learning_catalog.learning_silver.CleanedMonthlySales
