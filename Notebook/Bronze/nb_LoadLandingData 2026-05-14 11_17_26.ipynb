# %%
dfpatient = spark.read.csv("/Volumes/learning_catalog/learning_schema/manage_landing_files/patients.csv", header=True, inferSchema = True)
dfpatient.display()



# /Volumes/learning_catalog/learning_schema/manage_landing_files/patients.csv
