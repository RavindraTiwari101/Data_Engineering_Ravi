-- %%
-- Create table in bronze layer
CREATE OR REPLACE TABLE learning_catalog.learning_bronze.rawMonthlySales
(
    sale_id string, 
    product string,
    category string,
    quantity string,
    price string,
    sale_date string,
    region string,
    ingest_ts timestamp
);

select * from learning_catalog.learning_bronze.rawMonthlySales
describe learning_catalog.learning_bronze.rawMonthlySales
describe history  learning_catalog.learning_bronze.rawMonthlySales
TRUNCATE TABLE learning_catalog.learning_bronze.rawMonthlySales
drop table learning_catalog.learning_bronze.rawmonthlysales
